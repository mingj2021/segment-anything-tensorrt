# %%
! nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3080 Ti (UUID: GPU-ec04475b-ddbc-f088-6ee9-45a2440b7d44)

# %%
! cd build && cmake --build . --config release --target  sampleSAM2
# Out:
# [ 50%] Building CXX object CMakeFiles/sampleSAM2.dir/main_vim_h.cpp.o
# In file included from /workspace/segment-anything-tensorrt/main_vim_h.cpp:1:
# /workspace/segment-anything-tensorrt/sam.h: In constructor ‘SamEmbedding::SamEmbedding(std::string, std::shared_ptr<nvinfer1::ICudaEngine>&, cv::Mat, int, int)’:
# /workspace/segment-anything-tensorrt/sam.h:97:48: warning: ‘int32_t nvinfer1::ICudaEngine::getNbBindings() const’ is deprecated [-Wdeprecated-declarations]
#    97 |     for (int i = 0; i < mEngine->getNbBindings(); i++)
#       |                                                ^
# In file included from /usr/include/x86_64-linux-gnu/NvInfer.h:17,
#                  from /workspace/segment-anything-tensorrt/./commons/general.h:4,
#                  from /workspace/segment-anything-tensorrt/./commons/buffers.h:4,
#                  from /workspace/segment-anything-tensorrt/sam.h:4,
#                  from /workspace/segment-anything-tensorrt/main_vim_h.cpp:1:
# ...

# %%
! cd build && ./sampleSAM2
# Out:
# CUDA lazy loading is not enabled. Enabling it can significantly reduce device memory usage. See `CUDA_MODULE_LOADING` in https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#env-vars
# parsers/onnx/onnx2trt_utils.cpp:375: Your ONNX model has been generated with INT64 weights, while TensorRT does not natively support INT64. Attempting to cast down to INT32.
# parsers/onnx/onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# parsers/onnx/onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# parsers/onnx/onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# parsers/onnx/onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# parsers/onnx/onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# parsers/onnx/onnx2trt_utils.cpp:403: One or more weights outside the range of INT32 was clamped
# ...

# %%
from IPython.display import Image

Image(filename =r'build/img1111.jpg')
